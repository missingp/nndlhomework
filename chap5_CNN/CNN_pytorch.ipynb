# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1      ,# grey  
                out_channels=32     ,
                kernel_size=7      ,
                stride=1           ,
                padding=3          ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=5,
                stride=1,
                padding='same'
            ),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# Failed download. Trying https -> http instead. Downloading http://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:03<00:00, 2778986.32it/s]
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 506769.69it/s]
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# Failed download. Trying https -> http instead. Downloading http://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1243747.25it/s]
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2397800.98it/s]
# d:\anna\envs\py39\lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\missi\AppData\Local\Temp\ipykernel_14992\3502269284.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# d:\anna\envs\py39\lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
# C:\Users\missi\AppData\Local\Temp\ipykernel_14992\3502269284.py:72: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.222 ==========
# ========== 40 ===== ===== test accuracy is  0.43 ==========
# ========== 60 ===== ===== test accuracy is  0.49 ==========
# ========== 80 ===== ===== test accuracy is  0.638 ==========
# ========== 100 ===== ===== test accuracy is  0.658 ==========
# ========== 120 ===== ===== test accuracy is  0.706 ==========
# ========== 140 ===== ===== test accuracy is  0.7 ==========
# ========== 160 ===== ===== test accuracy is  0.73 ==========
# ========== 180 ===== ===== test accuracy is  0.756 ==========
# ========== 200 ===== ===== test accuracy is  0.802 ==========
# ========== 220 ===== ===== test accuracy is  0.824 ==========
# ========== 240 ===== ===== test accuracy is  0.81 ==========
# ========== 260 ===== ===== test accuracy is  0.83 ==========
# ========== 280 ===== ===== test accuracy is  0.86 ==========
# ========== 300 ===== ===== test accuracy is  0.88 ==========
# ========== 320 ===== ===== test accuracy is  0.868 ==========
# ========== 340 ===== ===== test accuracy is  0.86 ==========
# ========== 360 ===== ===== test accuracy is  0.878 ==========
# ========== 380 ===== ===== test accuracy is  0.892 ==========
# ========== 400 ===== ===== test accuracy is  0.888 ==========
# ========== 420 ===== ===== test accuracy is  0.888 ==========
# ========== 440 ===== ===== test accuracy is  0.908 ==========
# ========== 460 ===== ===== test accuracy is  0.878 ==========
# ========== 480 ===== ===== test accuracy is  0.912 ==========
# ========== 500 ===== ===== test accuracy is  0.898 ==========
# ========== 520 ===== ===== test accuracy is  0.906 ==========
# ========== 540 ===== ===== test accuracy is  0.906 ==========
# ========== 560 ===== ===== test accuracy is  0.898 ==========
# ========== 580 ===== ===== test accuracy is  0.912 ==========
# ========== 600 ===== ===== test accuracy is  0.908 ==========
# ========== 620 ===== ===== test accuracy is  0.91 ==========
# ========== 640 ===== ===== test accuracy is  0.904 ==========
# ========== 660 ===== ===== test accuracy is  0.924 ==========
# ========== 680 ===== ===== test accuracy is  0.934 ==========
# ========== 700 ===== ===== test accuracy is  0.93 ==========
# ========== 720 ===== ===== test accuracy is  0.93 ==========
# ========== 740 ===== ===== test accuracy is  0.936 ==========
# ========== 760 ===== ===== test accuracy is  0.938 ==========
# ========== 780 ===== ===== test accuracy is  0.934 ==========
# ========== 800 ===== ===== test accuracy is  0.926 ==========
# ========== 820 ===== ===== test accuracy is  0.94 ==========
# ========== 840 ===== ===== test accuracy is  0.938 ==========
# ========== 860 ===== ===== test accuracy is  0.916 ==========
# ========== 880 ===== ===== test accuracy is  0.94 ==========
# ========== 900 ===== ===== test accuracy is  0.952 ==========
# ========== 920 ===== ===== test accuracy is  0.932 ==========
# ========== 940 ===== ===== test accuracy is  0.936 ==========
# ========== 960 ===== ===== test accuracy is  0.946 ==========
# ========== 980 ===== ===== test accuracy is  0.948 ==========
# ========== 1000 ===== ===== test accuracy is  0.934 ==========
# ========== 1020 ===== ===== test accuracy is  0.938 ==========
# ========== 1040 ===== ===== test accuracy is  0.95 ==========
# ========== 1060 ===== ===== test accuracy is  0.948 ==========
# ========== 1080 ===== ===== test accuracy is  0.95 ==========
# ========== 1100 ===== ===== test accuracy is  0.942 ==========
# ========== 1120 ===== ===== test accuracy is  0.95 ==========
# ========== 1140 ===== ===== test accuracy is  0.946 ==========
# ========== 1160 ===== ===== test accuracy is  0.954 ==========
# ========== 1180 ===== ===== test accuracy is  0.946 ==========
# ========== 20 ===== ===== test accuracy is  0.954 ==========
# ========== 40 ===== ===== test accuracy is  0.96 ==========
# ========== 60 ===== ===== test accuracy is  0.962 ==========
# ========== 80 ===== ===== test accuracy is  0.966 ==========
# ========== 100 ===== ===== test accuracy is  0.954 ==========
# ========== 120 ===== ===== test accuracy is  0.962 ==========
# ========== 140 ===== ===== test accuracy is  0.958 ==========
# ========== 160 ===== ===== test accuracy is  0.954 ==========
# ========== 180 ===== ===== test accuracy is  0.96 ==========
# ========== 200 ===== ===== test accuracy is  0.954 ==========
# ========== 220 ===== ===== test accuracy is  0.964 ==========
# ========== 240 ===== ===== test accuracy is  0.956 ==========
# ========== 260 ===== ===== test accuracy is  0.96 ==========
# ========== 280 ===== ===== test accuracy is  0.95 ==========
# ========== 300 ===== ===== test accuracy is  0.968 ==========
# ========== 320 ===== ===== test accuracy is  0.964 ==========
# ========== 340 ===== ===== test accuracy is  0.964 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.952 ==========
# ========== 400 ===== ===== test accuracy is  0.964 ==========
# ========== 420 ===== ===== test accuracy is  0.956 ==========
# ========== 440 ===== ===== test accuracy is  0.966 ==========
# ========== 460 ===== ===== test accuracy is  0.968 ==========
# ========== 480 ===== ===== test accuracy is  0.964 ==========
# ========== 500 ===== ===== test accuracy is  0.968 ==========
# ========== 520 ===== ===== test accuracy is  0.972 ==========
# ========== 540 ===== ===== test accuracy is  0.966 ==========
# ========== 560 ===== ===== test accuracy is  0.96 ==========
# ========== 580 ===== ===== test accuracy is  0.972 ==========
# ========== 600 ===== ===== test accuracy is  0.968 ==========
# ========== 620 ===== ===== test accuracy is  0.964 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.972 ==========
# ========== 680 ===== ===== test accuracy is  0.964 ==========
# ========== 700 ===== ===== test accuracy is  0.972 ==========
# ========== 720 ===== ===== test accuracy is  0.968 ==========
# ========== 740 ===== ===== test accuracy is  0.956 ==========
# ========== 760 ===== ===== test accuracy is  0.964 ==========
# ========== 780 ===== ===== test accuracy is  0.966 ==========
# ========== 800 ===== ===== test accuracy is  0.968 ==========
# ========== 820 ===== ===== test accuracy is  0.972 ==========
# ========== 840 ===== ===== test accuracy is  0.972 ==========
# ========== 860 ===== ===== test accuracy is  0.966 ==========
# ========== 880 ===== ===== test accuracy is  0.968 ==========
# ========== 900 ===== ===== test accuracy is  0.974 ==========
# ========== 920 ===== ===== test accuracy is  0.962 ==========
# ========== 940 ===== ===== test accuracy is  0.964 ==========
# ========== 960 ===== ===== test accuracy is  0.97 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.978 ==========
# ========== 1040 ===== ===== test accuracy is  0.958 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.962 ==========
# ========== 1100 ===== ===== test accuracy is  0.97 ==========
# ========== 1120 ===== ===== test accuracy is  0.972 ==========
# ========== 1140 ===== ===== test accuracy is  0.966 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.96 ==========
# ========== 20 ===== ===== test accuracy is  0.964 ==========
# ========== 40 ===== ===== test accuracy is  0.974 ==========
# ========== 60 ===== ===== test accuracy is  0.974 ==========
# ========== 80 ===== ===== test accuracy is  0.972 ==========
# ========== 100 ===== ===== test accuracy is  0.968 ==========
# ========== 120 ===== ===== test accuracy is  0.97 ==========
# ========== 140 ===== ===== test accuracy is  0.976 ==========
# ========== 160 ===== ===== test accuracy is  0.98 ==========
# ========== 180 ===== ===== test accuracy is  0.968 ==========
# ========== 200 ===== ===== test accuracy is  0.96 ==========
# ========== 220 ===== ===== test accuracy is  0.972 ==========
# ========== 240 ===== ===== test accuracy is  0.978 ==========
# ========== 260 ===== ===== test accuracy is  0.976 ==========
# ========== 280 ===== ===== test accuracy is  0.974 ==========
# ========== 300 ===== ===== test accuracy is  0.976 ==========
# ========== 320 ===== ===== test accuracy is  0.974 ==========
# ========== 340 ===== ===== test accuracy is  0.976 ==========
# ========== 360 ===== ===== test accuracy is  0.974 ==========
# ========== 380 ===== ===== test accuracy is  0.972 ==========
# ========== 400 ===== ===== test accuracy is  0.97 ==========
# ========== 420 ===== ===== test accuracy is  0.97 ==========
# ========== 440 ===== ===== test accuracy is  0.984 ==========
# ========== 460 ===== ===== test accuracy is  0.976 ==========
# ========== 480 ===== ===== test accuracy is  0.972 ==========
# ========== 500 ===== ===== test accuracy is  0.97 ==========
# ========== 520 ===== ===== test accuracy is  0.97 ==========
# ========== 540 ===== ===== test accuracy is  0.976 ==========
# ========== 560 ===== ===== test accuracy is  0.968 ==========
# ========== 580 ===== ===== test accuracy is  0.98 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.968 ==========
# ========== 680 ===== ===== test accuracy is  0.972 ==========
# ========== 700 ===== ===== test accuracy is  0.974 ==========
# ========== 720 ===== ===== test accuracy is  0.98 ==========
# ========== 740 ===== ===== test accuracy is  0.974 ==========
# ========== 760 ===== ===== test accuracy is  0.98 ==========
# ========== 780 ===== ===== test accuracy is  0.98 ==========
# ========== 800 ===== ===== test accuracy is  0.972 ==========
# ========== 820 ===== ===== test accuracy is  0.98 ==========
# ========== 840 ===== ===== test accuracy is  0.974 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.984 ==========
# ========== 900 ===== ===== test accuracy is  0.978 ==========
# ========== 920 ===== ===== test accuracy is  0.978 ==========
# ========== 940 ===== ===== test accuracy is  0.978 ==========
# ========== 960 ===== ===== test accuracy is  0.97 ==========
# ========== 980 ===== ===== test accuracy is  0.978 ==========
# ========== 1000 ===== ===== test accuracy is  0.976 ==========
# ========== 1020 ===== ===== test accuracy is  0.976 ==========
# ========== 1040 ===== ===== test accuracy is  0.97 ==========
# ========== 1060 ===== ===== test accuracy is  0.98 ==========
# ========== 1080 ===== ===== test accuracy is  0.982 ==========
# ========== 1100 ===== ===== test accuracy is  0.974 ==========
# ========== 1120 ===== ===== test accuracy is  0.978 ==========
# ========== 1140 ===== ===== test accuracy is  0.978 ==========
# ========== 1160 ===== ===== test accuracy is  0.978 ==========
# ========== 1180 ===== ===== test accuracy is  0.978 ==========
